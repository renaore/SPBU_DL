# %% [markdown]
# ## Детекция клеток

# %% [markdown]
# Ваша задача: обучить YOLO для детекции дрожжевых клеток и микроструктур (см. [07_object_detection.ipynb](../workshops/07_object_detection.ipynb)). Всё необходимое для запуска обучения вы можете взять из ноутбука с практикой, доделать нужно будет самую малость:
# - реализовать расчёт Mean Average Precision для всего валидационного сета
# - попробовать привести regression loss к виду, который используется в Yolo9000 и YoloV3
# - подобрать лучшие размеры якорных рамок с помощью кластеризации
#
# Основная цель: любыми средствами добиться $mAP > 0.6$ на валидации.
#
# Используйте класс `torchmetrics.detection.MeanAveragePrecision` для расчёта $mAP$.
#
# Нас будет интересовать именно значение `map` в словаре со всеми метриками - это mean average precision, усреднённый по всем отсечкам intersection over union в диапазоне $[0.5, 0.95]$ (см. документацию к классу).
#
# При решении можно пользоваться `lightning` или писать цикл обучения вручную. В последнем случае не забудьте вручную отправить модель и батчи на GPU, чтобы обучалось быстрее

# %% [markdown]
# ### Задание 1 (3 балла). Цикл обучения с расчётом Mean Average Precision
#
# Запустите обучение модели из практики на всём обучающем датасете, выведите значение $mAP$ на валидационном датасете после окончания обучения.
#
# В этом задании добейтесь $mAP > 0.3$, если всё сделано правильно - для этого должно хватать 30-50 эпох.

# %%
! wget https://tudatalib.ulb.tu-darmstadt.de/bitstream/handle/tudatalib/3799/yeast_cell_in_microstructures_dataset.zip
! unzip yeast_cell_in_microstructures_dataset.zip -d yeast_cell_in_microstructures_dataset
# Out:
# --2024-10-27 07:17:46--  https://tudatalib.ulb.tu-darmstadt.de/bitstream/handle/tudatalib/3799/yeast_cell_in_microstructures_dataset.zip
# Resolving tudatalib.ulb.tu-darmstadt.de (tudatalib.ulb.tu-darmstadt.de)... 130.83.152.157
# Connecting to tudatalib.ulb.tu-darmstadt.de (tudatalib.ulb.tu-darmstadt.de)|130.83.152.157|:443... connected.
# HTTP request sent, awaiting response... 200 200
# Length: unspecified [application/zip]
# Saving to: ‘yeast_cell_in_microstructures_dataset.zip’
#
# yeast_cell_in_micro     [            <=>     ]  92.04M  21.2MB/s    in 5.4s
#
# Last-modified header invalid -- time-stamp ignored.
# 2024-10-27 07:17:53 (16.9 MB/s) - ‘yeast_cell_in_microstructures_dataset.zip’ saved [96507334]
#
# Archive:  yeast_cell_in_microstructures_dataset.zip
#    creating: yeast_cell_in_microstructures_dataset/test/
#    creating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/395.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/303.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/352.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/170.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/160.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/202.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/154.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/294.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/236.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/78.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/418.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/187.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/307.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/280.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/263.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/164.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/135.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/317.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/257.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/346.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/206.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/79.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/419.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/175.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/390.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/291.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/100.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/151.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/373.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/322.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/196.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/409.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/458.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/429.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/367.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/182.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/171.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/120.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/104.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/377.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/439.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/1.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/76.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/416.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/507.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/447.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/13.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/42.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/406.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/66.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/426.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/46.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/477.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/72.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/412.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/467.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/436.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/269.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/329.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/22.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/73.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/452.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/512.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/248.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/308.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/219.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/77.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/417.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/84.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/12.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/491.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/53.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/516.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/36.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/288.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/148.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/486.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/15.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/424.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/44.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/83.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/410.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/21.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/501.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/441.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/400.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/60.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/93.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/414.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/420.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/11.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/50.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/515.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/504.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/444.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/41.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/65.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/9.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/96.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/118.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/487.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/45.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/82.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/411.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/20.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/450.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/510.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/159.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/388.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/89.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/142.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/292.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/315.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/6.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/275.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/364.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/181.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/241.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/301.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/340.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/191.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/162.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/156.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/498.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/2.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/287.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/116.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/122.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/351.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/300.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/310.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/250.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/132.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/297.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/499.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/3.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/177.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/244.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/184.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/355.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/143.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/221.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/320.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/293.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/102.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/194.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/314.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/bounding_boxes/167.pt
#    creating: yeast_cell_in_microstructures_dataset/test/classes/
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/395.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/303.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/352.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/170.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/160.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/202.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/154.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/294.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/236.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/78.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/418.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/187.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/307.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/280.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/263.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/164.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/135.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/317.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/257.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/346.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/206.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/79.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/419.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/175.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/390.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/291.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/100.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/151.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/373.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/322.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/196.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/409.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/458.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/429.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/367.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/182.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/171.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/120.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/104.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/377.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/439.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/1.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/76.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/416.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/507.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/447.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/13.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/42.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/406.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/66.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/426.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/46.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/477.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/72.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/412.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/467.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/436.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/269.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/329.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/22.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/73.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/452.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/512.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/248.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/308.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/219.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/77.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/417.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/84.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/12.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/491.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/53.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/516.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/36.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/288.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/148.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/486.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/15.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/424.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/44.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/83.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/410.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/21.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/501.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/441.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/400.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/60.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/93.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/414.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/420.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/11.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/50.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/515.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/504.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/444.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/41.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/65.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/9.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/96.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/118.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/487.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/45.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/82.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/411.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/20.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/450.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/510.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/159.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/388.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/89.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/142.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/292.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/315.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/6.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/275.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/364.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/181.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/241.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/301.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/340.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/191.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/162.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/156.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/498.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/2.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/287.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/116.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/122.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/351.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/300.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/310.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/250.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/132.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/297.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/499.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/3.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/177.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/244.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/184.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/355.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/143.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/221.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/320.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/293.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/102.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/194.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/314.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/classes/167.pt
#    creating: yeast_cell_in_microstructures_dataset/test/instances/
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/395.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/303.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/352.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/170.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/160.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/202.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/154.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/294.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/236.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/78.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/418.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/187.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/307.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/280.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/263.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/164.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/135.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/317.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/257.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/346.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/206.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/79.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/419.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/175.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/390.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/291.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/100.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/151.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/373.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/322.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/196.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/409.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/458.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/429.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/367.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/182.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/171.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/120.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/104.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/377.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/439.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/1.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/76.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/416.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/507.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/447.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/13.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/42.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/406.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/66.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/426.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/46.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/477.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/72.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/412.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/467.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/436.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/269.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/329.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/22.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/73.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/452.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/512.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/248.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/308.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/219.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/77.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/417.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/84.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/12.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/491.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/53.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/516.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/36.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/288.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/148.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/486.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/15.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/424.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/44.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/83.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/410.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/21.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/501.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/441.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/400.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/60.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/93.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/414.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/420.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/11.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/50.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/515.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/504.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/444.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/41.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/65.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/9.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/96.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/118.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/487.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/45.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/82.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/411.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/20.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/450.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/510.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/159.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/388.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/89.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/142.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/292.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/315.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/6.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/275.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/364.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/181.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/241.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/301.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/340.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/191.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/162.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/156.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/498.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/2.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/287.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/116.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/122.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/351.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/300.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/310.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/250.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/132.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/297.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/499.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/3.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/177.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/244.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/184.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/355.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/143.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/221.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/320.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/293.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/102.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/194.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/314.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/instances/167.pt
#    creating: yeast_cell_in_microstructures_dataset/test/inputs/
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/395.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/303.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/352.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/170.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/160.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/202.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/154.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/294.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/236.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/78.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/418.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/187.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/307.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/280.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/263.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/164.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/135.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/317.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/257.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/346.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/206.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/79.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/419.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/175.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/390.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/291.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/100.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/151.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/373.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/322.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/196.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/409.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/458.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/429.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/367.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/182.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/171.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/120.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/104.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/377.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/439.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/1.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/76.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/416.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/507.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/447.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/13.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/42.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/406.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/66.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/426.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/46.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/477.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/72.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/412.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/467.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/436.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/269.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/329.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/22.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/73.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/452.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/512.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/248.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/308.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/219.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/77.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/417.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/84.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/12.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/491.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/53.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/516.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/36.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/288.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/148.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/486.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/15.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/424.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/44.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/83.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/410.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/21.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/501.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/441.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/400.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/60.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/93.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/414.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/420.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/11.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/50.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/515.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/504.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/444.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/41.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/65.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/9.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/96.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/118.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/487.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/45.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/82.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/411.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/20.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/450.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/510.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/159.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/388.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/89.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/142.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/292.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/315.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/6.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/275.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/364.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/181.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/241.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/301.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/340.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/191.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/162.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/156.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/498.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/2.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/287.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/116.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/122.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/351.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/300.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/310.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/250.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/132.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/297.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/499.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/3.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/177.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/244.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/184.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/355.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/143.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/221.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/320.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/293.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/102.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/194.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/314.pt
#   inflating: yeast_cell_in_microstructures_dataset/test/inputs/167.pt
#    creating: yeast_cell_in_microstructures_dataset/train/
#    creating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/479.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/19.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/428.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/48.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/226.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/337.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/277.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/115.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/284.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/144.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/212.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/121.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/131.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/193.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/313.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/385.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/327.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/376.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/58.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/438.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/469.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/0.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/509.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/29.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/449.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/216.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/356.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/247.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/125.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/174.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/bounding_boxes/333.pt
# ...
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/106.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/386.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/88.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/126.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/283.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/361.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/330.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/270.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/260.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/231.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/153.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/382.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/205.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/254.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/98.pt
#    creating: yeast_cell_in_microstructures_dataset/val/
#    creating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/243.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/342.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/253.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/105.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/267.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/273.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/140.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/306.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/272.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/363.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/380.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/347.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/285.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/343.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/468.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/358.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/473.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/480.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/339.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/503.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/33.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/238.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/427.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/16.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/359.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/481.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/67.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/399.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/482.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/128.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/34.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/289.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/92.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/393.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/195.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/204.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/255.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/99.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/396.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/334.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/225.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/180.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/324.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/304.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/112.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/392.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/371.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/345.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/7.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/.DS_Store
#    creating: yeast_cell_in_microstructures_dataset/val/classes/
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/243.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/342.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/253.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/105.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/267.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/273.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/140.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/306.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/272.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/363.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/380.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/347.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/285.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/343.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/468.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/358.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/473.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/480.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/339.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/503.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/33.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/238.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/427.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/16.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/359.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/481.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/67.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/399.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/482.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/128.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/34.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/289.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/92.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/393.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/195.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/204.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/255.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/99.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/396.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/334.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/225.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/180.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/324.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/304.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/112.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/392.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/371.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/345.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/7.pt
#    creating: yeast_cell_in_microstructures_dataset/val/instances/
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/243.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/342.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/253.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/105.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/267.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/273.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/140.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/306.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/272.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/363.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/380.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/347.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/285.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/343.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/468.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/358.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/473.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/480.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/339.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/503.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/33.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/238.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/427.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/16.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/359.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/481.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/67.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/399.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/482.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/128.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/34.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/289.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/92.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/393.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/195.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/204.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/255.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/99.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/396.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/334.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/225.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/180.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/324.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/304.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/112.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/392.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/371.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/345.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/7.pt
#    creating: yeast_cell_in_microstructures_dataset/val/inputs/
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/243.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/342.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/253.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/105.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/267.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/273.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/140.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/306.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/272.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/363.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/380.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/347.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/285.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/343.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/468.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/358.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/473.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/480.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/339.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/503.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/33.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/238.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/427.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/16.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/359.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/481.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/67.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/399.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/482.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/128.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/34.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/289.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/92.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/393.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/195.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/204.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/255.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/99.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/396.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/334.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/225.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/180.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/324.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/304.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/112.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/392.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/371.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/345.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/7.pt

# %%
# %%capture
# !pip install lightning
import lightning as L
from pathlib import Path

import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import torch
from matplotlib.figure import Figure
from torch import Tensor, nn
from torch.utils.data import DataLoader, Dataset
from torchmetrics.functional.detection import intersection_over_union
from torchvision.ops.boxes import box_convert
from lightning.pytorch.loggers import CSVLogger

# %%
def process_yolo_preds(preds: Tensor, rescaled_anchors: Tensor) -> tuple[Tensor, Tensor, Tensor]:
    """
    Преобразование выходов модели в
    1. Логит наличия объекта (вероятность получается применением сигмоиды)
    2. Положение рамки относительно ячейки в формате cxcywh
    3. Логиты классов (вероятности получаются применением softmax)
    """

    rescaled_anchors = rescaled_anchors.view(1, len(rescaled_anchors), 1, 1, 2)
    box_predictions = preds[..., 1:5].clone()

    box_predictions[..., 0:2] = torch.sigmoid(box_predictions[..., 0:2])
    box_predictions[..., 2:] = torch.exp(box_predictions[..., 2:]) * rescaled_anchors

    scores = preds[..., 0:1]
    return scores, box_predictions, preds[..., 5:]

# %%
GRID_SIZE = 8
IMAGE_SIZE = 256
ANCHORS = [
    [48, 72],
    # [64, 64],
    # [72, 48],
]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
rescaled_anchors = torch.tensor(ANCHORS) / IMAGE_SIZE * GRID_SIZE
rescaled_anchors = rescaled_anchors.to(device)

# %%
class CNNBlock(nn.Module):
    def __init__(self, in_channels: int, out_channels: int, **kwargs):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels)
        self.activation = nn.LeakyReLU(0.1)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return self.activation(x)

class TinyYOLO(nn.Module):
    def __init__(self, num_classes: int = 2, num_anchors: int = 1, in_channels: int = 1) -> None:
        super().__init__()
        self.num_classes = num_classes
        self.in_channels = in_channels
        self.num_anchors = num_anchors
        self.layers = nn.Sequential(
            CNNBlock(1, 16, kernel_size=3, stride=2, padding=1, dilation=2),
            CNNBlock(16, 32, kernel_size=3, stride=2, padding=1, dilation=2),
            CNNBlock(32, 64, kernel_size=3, stride=2, padding=1, dilation=2),
            CNNBlock(64, 128, kernel_size=3, stride=2, padding=1, groups=8),
            CNNBlock(128, 256, kernel_size=3, stride=1, padding=1, groups=8),
            CNNBlock(256, 256, kernel_size=3, stride=1, padding=1, groups=16),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(256, num_anchors * (num_classes + 5), kernel_size=1)
        )

    def forward(self, x: Tensor) -> Tensor:
        x = self.layers(x)
        B, _, W, H = x.shape
        x = x.view(B, self.num_anchors, self.num_classes + 5, W, H)  # B A F W H
        x = x.permute(0, 1, 3, 4, 2)  # B A W H F
        return x

# %%
def iou_wh(wh1: Tensor, wh2: Tensor) -> Tensor:
    # IoU based on width and height of bboxes

    # intersection
    intersection_area = torch.min(wh1[..., 0], wh2[..., 0]) * torch.min(wh1[..., 1], wh2[..., 1])

    # union
    box1_area = wh1[..., 0] * wh1[..., 1]
    box2_area = wh2[..., 0] * wh2[..., 1]
    union_area = box1_area + box2_area - intersection_area

    iou_score = intersection_area / union_area
    return iou_score


def boxes_to_cells(
    boxes: Tensor,
    classes: Tensor,
    rescaled_anchors: Tensor,
    grid_size: int = 8,
    ignore_iou_thresh: float = 0.5,
) -> Tensor:
    """
    Переводит bbox представление в клеточное представление, где каждая рамка -
    (id класса, вероятность нахождения объекта, cx, cy, w, h), а клеточное представление
    имеет размер (batch_size, n_anchors, grid_size, grid_size, 6), в последней размерности
    хранятся признаки ячейки: класс объекта, вероятность объекта, координаты и размеры рамки
    относительно ячейки

    Args:
        boxes (Tensor): тензор со всеми рамками
        classes (Tensor): тензор с id классов объектов
        rescaled_anchors (Tensor): тензор размера (n_anchors, 2) с размерами якорей в долях от размеров ячейки
        grid_size (int): размер сетки,
        ignore_iou_thresh (float, optional): значение IoU для рамок, при котором ячейка,
            занятая более чем одним объектом, будет специально помечена для игнорирования
    """
    targets = torch.zeros((len(rescaled_anchors), grid_size, grid_size, 6))

    # Каждой рамке сопоставляем клетку и наиболее подходящий якорь
    for box, class_label in zip(boxes, classes):
        iou_anchors = iou_wh(box[2:4], rescaled_anchors / grid_size)
        anchor_indices = iou_anchors.argsort(descending=True, dim=0)
        x, y, width, height = box

        # Относим рамку к наиболее подходящему якорю
        has_anchor = False
        for anchor_idx in anchor_indices:
            s = grid_size

            # Определяем клетку, к которой относится рамка
            i, j = int(s * y), int(s * x)
            anchor_taken = targets[anchor_idx, i, j, 0]

            # Проверяем, доступен ли якорная рамка для текущей ячейки
            if not anchor_taken and not has_anchor:
                # Пересчитываем координаты по отношению к клетке
                x_cell, y_cell = s * x - j, s * y - i
                width_cell, height_cell = (width * s, height * s)
                box_coordinates = torch.tensor([x_cell, y_cell, width_cell, height_cell])

                # Заполняем содержимое для выбранной клетки
                targets[anchor_idx, i, j, 0] = 1  # указатель, что в клетке есть объект
                targets[anchor_idx, i, j, 1:5] = box_coordinates
                targets[anchor_idx, i, j, 5] = int(class_label)

                has_anchor = True

            # Если якорь уже выбран, проверим IoU, если больше threshold - пометим клетку -1
            elif not anchor_taken and iou_anchors[anchor_idx] > ignore_iou_thresh:
                targets[anchor_idx, i, j, 0] = -1

    return targets

# %%
class YeastDetectionDataset(Dataset):
    def __init__(
        self, subset_dir: Path, anchors: list[tuple[int, int]], image_size: int, grid_size: int = 8
    ) -> None:
        super().__init__()
        self.subset_dir = subset_dir
        self.items = list((self.subset_dir / "inputs").glob("*.pt"))
        # Ignore IoU threshold
        self.ignore_iou_thresh = 0.5
        self.rescaled_anchors = torch.tensor(anchors) / image_size * grid_size
        self.grid_size = grid_size
        self.image_size = image_size

    def __len__(self) -> int:
        return len(self.items)

    def __getitem__(self, index: int) -> tuple[Tensor, Tensor]:
        image_path = self.items[index]
        # load everything
        image = torch.load(image_path, weights_only=True).unsqueeze(0)
        classes = (
            torch.load(self.subset_dir / "classes" / image_path.parts[-1], weights_only=True) + 1
        )
        boxes = torch.load(
            self.subset_dir / "bounding_boxes" / image_path.parts[-1], weights_only=True
        )
        boxes = box_convert(boxes, "xyxy", "cxcywh") / self.image_size

        # convert boxes to cells
        targets = boxes_to_cells(
            boxes, classes, self.rescaled_anchors, self.grid_size, self.ignore_iou_thresh
        )
        return image, targets

# %%
train_dataset = YeastDetectionDataset(
    Path("yeast_cell_in_microstructures_dataset/train"), anchors=ANCHORS, image_size=256
)
val_dataset = YeastDetectionDataset(Path("yeast_cell_in_microstructures_dataset/val"), anchors=ANCHORS, image_size=256)

batch_size = 32
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

# %%
def cells_to_bboxes(cells: Tensor, rescaled_anchors: Tensor, is_predictions=False) -> Tensor:
    """
    Переводит клеточное представление в bbox представление, где каждая рамка -
    (id класса, вероятность нахождения объекта, cx, cy, w, h), а клеточное представление
    имеет размер (batch_size, n_anchors, grid_size, grid_size, 6), в последней размерности
    хранятся признаки ячейки: класс объекта, вероятность объекта, координаты и размеры рамки
    относительно ячейки

    Args:
        cells (Tensor): тензор размера (batch_size, n_anchors, width, height, 6)
        rescaled_anchors (Tensor): тензор размера (n_anchors, 2) с размерами якорей в долях от размеров ячейки
        is_predictions (bool, optional): являются ли входные ячейки предсказаниями или верной аннотацией.
    """

    if is_predictions:
        scores, box_predictions, logits = process_yolo_preds(cells, rescaled_anchors)
        scores = torch.sigmoid(scores)
        best_class = torch.argmax(logits, dim=-1).unsqueeze(-1) + 1

    else:
        box_predictions = cells[..., 1:5].clone()
        scores = cells[..., 0:1]
        best_class = cells[..., 5:6]

    # масштабируем размер рамок [0, grid_size] -> [0, 1]
    _, _, H, W, _ = cells.shape
    range_y, range_x = torch.meshgrid(
        torch.arange(H, dtype=cells.dtype, device=cells.device),
        torch.arange(W, dtype=cells.dtype, device=cells.device),
        indexing="ij",
    )
    x = torch.cat(
        [
            best_class,
            scores,
            (box_predictions[..., 0:1] + range_x[None, None, :, :, None]) / W,  # X center
            (box_predictions[..., 1:2] + range_y[None, None, :, :, None]) / H,  # Y center
            box_predictions[..., 2:3] / W,  # Width
            box_predictions[..., 3:4] / H,  # Height
        ],
        -1,
    )

    return x.view(-1, 6)

# %%
class YOLOLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        self.bce = nn.BCEWithLogitsLoss()
        self.cross_entropy = nn.CrossEntropyLoss()

    def forward(self, pred: Tensor, target: Tensor, anchors: Tensor) -> Tensor:
        # ниже входные тензоры будут меняться на месте, так что склонируем их
        pred = pred.clone()
        target = target.clone()

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        pred = pred.to(device)
        target = target.to(device)
        anchors = anchors.to(device)

        # разделяем рамки на содержащие объекты и не содержащие
        # NB: ещё могут быть -1, куда отнеслось более 1 объекта - их не учитываем
        obj = target[..., 0] == 1
        no_obj = target[..., 0] == 0

        # преобразуем предсказания bbox
        scores, pred_boxes, logits = process_yolo_preds(pred, anchors)

        # no object loss: кросс-энтропия вместо MSE
        no_object_loss = self.bce(
            (scores[no_obj]),
            (target[..., 0:1][no_obj]),
        )

        # object loss: учим предсказывать IoU
        ious = intersection_over_union(pred_boxes[obj], target[..., 1:5][obj]).detach()
        object_loss = self.mse(scores[obj].sigmoid(), ious * target[..., 0:1][obj])

        # box coordinate loss: логарифмируем размеры рамок перед расчётом MSE
        anchors = anchors.reshape(1, len(anchors), 1, 1, 2)
        pred[..., 1:3] = pred[..., 1:3].sigmoid()
        target[..., 3:5] = torch.log(1e-6 + target[..., 3:5] / anchors)
        box_loss = self.mse(pred[..., 1:5][obj], target[..., 1:5][obj])

        # class loss: здесь всё обычно
        class_loss = self.cross_entropy(logits[obj], target[..., 5][obj].long() - 1)

        # Total loss
        return box_loss + object_loss + no_object_loss + class_loss

# %%
from torchmetrics.detection import MeanAveragePrecision
from typing import Any, Callable, Type
from lightning.pytorch.utilities.types import EVAL_DATALOADERS, TRAIN_DATALOADERS, STEP_OUTPUT
from torch.utils.data import DataLoader

class Lit(L.LightningModule):
    def __init__(self, model: nn.Module, learning_rate: float, loss_func) -> None:
        super().__init__()
        self.save_hyperparameters(ignore=['model'])
        self.model = model
        self.learning_rate = learning_rate
        self.loss_func = loss_func
        self.metric = MeanAveragePrecision(iou_type="bbox", box_format="cxcywh", class_metrics=True)

    def training_step(
        self, batch: tuple[Tensor, Tensor], batch_idx: int
    ) -> STEP_OUTPUT:
        x, y = batch
        preds = self.model(x)

        loss = self.loss_func(preds, y, rescaled_anchors)
        self.log("train_loss", loss, on_epoch=True, on_step=False, prog_bar=True)
        return loss

    def validation_step(
        self, batch: tuple[Tensor, Tensor], batch_idx: int
    ) -> STEP_OUTPUT | None:
        x, y = batch
        preds = self.model(x)

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        preds = preds.to(device)
        y = y.to(device)

        loss = self.loss_func(preds, y, rescaled_anchors)

        predicted_boxes = cells_to_bboxes(preds, rescaled_anchors.to(device), is_predictions=True)
        target_boxes = cells_to_bboxes(y, rescaled_anchors.to(device))

        preds = [{'boxes': predicted_boxes[:, 2:], 'scores': predicted_boxes[:, 1], 'labels': predicted_boxes[:, 0].long()}]
        targets = [{'boxes': target_boxes[:, 2:], 'labels': target_boxes[:, 0].long()}]

        self.log("val_loss", loss, on_epoch=True, on_step=False, prog_bar=True)
        self.metric.update(preds, targets)
        metric_dict = self.metric.compute()
        self.log('val_map', metric_dict['map'],  prog_bar=True)
        self.metric.reset()

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate)
        return {
          "optimizer": optimizer,
          "lr_scheduler": torch.optim.lr_scheduler.MultiStepLR(
              optimizer, milestones=[10, 25], gamma=0.1
          ),
        }

# %%
torch.manual_seed(57)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = TinyYOLO(in_channels=1, num_anchors=len(rescaled_anchors), num_classes=2).to(device)
loss_func = YOLOLoss()

trainer = L.Trainer(
    accelerator='auto',
    max_epochs=30,
    limit_train_batches=None,
    limit_val_batches=None,
    log_every_n_steps=10,
    logger=CSVLogger(save_dir=".", version=0),
)
lit_module = Lit(
    model=model,
    learning_rate=0.005,
    loss_func=loss_func
).to(device)
trainer.fit(
    lit_module,
    train_loader,
    val_loader
)

trainer.validate(model=lit_module, dataloaders=val_loader)
# Out:
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name      | Type                 | Params | Mode
# -----------------------------------------------------------
# 0 | model     | TinyYOLO             | 109 K  | train
# 1 | loss_func | YOLOLoss             | 0      | train
# 2 | metric    | MeanAveragePrecision | 0      | train
# -----------------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 33        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=30` reached.
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         val_loss          │    0.10114265233278275    │
# │          val_map          │    0.38504067063331604    │
# └───────────────────────────┴───────────────────────────┘
# [{'val_loss': 0.10114265233278275, 'val_map': 0.38504067063331604}]

# %% [markdown]
# ### Задание 2 (2 балла). YoloV3 loss
#
# Мы упоминали, что на практике использовалась не совсем та же самая ошибка, что и в YOLO. В этом задании исправьте в классе YoloLoss ошибку регрессии, приведя её в соответствие с тем, как она описана в статье [YOLOv3: An Incremental Improvement](https://arxiv.org/abs/1804.02767) (см. раздел 2.1. Bounding Box Prediction).
#
# Запустите обучение с изменённой ошибкой, добейтесь $mAP > 0.3$

# %%
class YOLOv3Loss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        self.mse_sum = nn.MSELoss(reduction='sum')
        self.bce = nn.BCEWithLogitsLoss()
        self.cross_entropy = nn.CrossEntropyLoss()

    def forward(self, pred: Tensor, target: Tensor, anchors: Tensor) -> Tensor:
        # ниже входные тензоры будут меняться на месте, так что склонируем их
        pred = pred.clone()
        target = target.clone()

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        pred = pred.to(device)
        target = target.to(device)
        anchors = anchors.to(device)

        # разделяем рамки на содержащие объекты и не содержащие
        # NB: ещё могут быть -1, куда отнеслось более 1 объекта - их не учитываем
        obj = target[..., 0] == 1
        no_obj = target[..., 0] == 0

        # преобразуем предсказания bbox
        scores, pred_boxes, logits = process_yolo_preds(pred, anchors)

        # no object loss: кросс-энтропия вместо MSE
        no_object_loss = self.bce(
            (scores[no_obj]),
            (target[..., 0:1][no_obj]),
        )

        # object loss: учим предсказывать IoU
        ious = intersection_over_union(pred_boxes[obj], target[..., 1:5][obj]).detach()
        object_loss = self.mse(scores[obj].sigmoid(), ious * target[..., 0:1][obj])

        # box coordinate loss: логарифмируем размеры рамок перед расчётом MSE
        anchors = anchors.reshape(1, len(anchors), 1, 1, 2)
        pred[..., 1:3] = pred[..., 1:3].sigmoid()
        target[..., 3:5] = torch.log(1e-6 + target[..., 3:5] / anchors)
        box_loss = self.mse_sum(pred[..., 1:5][obj], target[..., 1:5][obj])

        # class loss: здесь всё обычно
        class_loss = self.cross_entropy(logits[obj], target[..., 5][obj].long() - 1)

        # Total loss
        return box_loss + object_loss + no_object_loss + class_loss

# %%
torch.manual_seed(7)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = TinyYOLO(in_channels=1, num_anchors=len(rescaled_anchors), num_classes=2).to(device)
loss_func = YOLOv3Loss()

trainer = L.Trainer(
    accelerator='auto',
    max_epochs=40,
    limit_train_batches=None,
    limit_val_batches=None,
    log_every_n_steps=10,
    logger=CSVLogger(save_dir=".", version=1),
)
lit_module = Lit(
    model=model,
    learning_rate=0.005,
    loss_func=loss_func
).to(device)
trainer.fit(
    lit_module,
    train_loader,
    val_loader
)

trainer.validate(model=lit_module, dataloaders=val_loader)
# Out:
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name      | Type                 | Params | Mode
# -----------------------------------------------------------
# 0 | model     | TinyYOLO             | 109 K  | train
# 1 | loss_func | YOLOv3Loss           | 0      | train
# 2 | metric    | MeanAveragePrecision | 0      | train
# -----------------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 34        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=40` reached.
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         val_loss          │     9.03639030456543      │
# │          val_map          │    0.35882315039634705    │
# └───────────────────────────┴───────────────────────────┘
# [{'val_loss': 9.03639030456543, 'val_map': 0.35882315039634705}]

# %% [markdown]
# ### Задание 3 (3 балла). Выбор anchors с помощью кластеризации
#
# В статье [YOLO9000: Better, Faster, Stronger](https://arxiv.org/abs/1612.08242) в разделе 2. Better. Dimension clusters описан способ выбора anchor boxes через кластеризацию обучающего датасета.
#
# Проделайте то же самое с вашим обучающим датасетом, чтобы выбрать несколько anchor boxes.
#
# В качестве результата выведите получившиеся размеры anchors для # Clusters = 5

# %%
import numpy as np

items = list((Path("yeast_cell_in_microstructures_dataset/train/inputs")).glob("*.pt"))
boxes = []
for image_path in items:
  box = torch.load(Path("yeast_cell_in_microstructures_dataset/train/bounding_boxes")
      / image_path.parts[-1], weights_only=True)
  for b in box:
    b = box_convert(b, "xyxy", "cxcywh")
    boxes.append(b[2:])

def iou_distance(box1, box2):
  return 1 - iou_wh(box1, box2)

def assign_clusters(boxes, centroids):
    clusters = []
    for x in boxes:
        distances = [iou_distance(x, torch.tensor(c)) for c in centroids]
        clusters.append(np.argmin(distances))
    return clusters

def compute_centroids(boxes, labels, k):
    centroids = []
    for i in range(k):
        points = np.array(boxes)[np.array(labels) == i]
        centroids.append(points.mean(axis=0))
    return np.array(centroids)

def k_means_iou(boxes, k, max_iter=200):
    centroids = np.array(boxes)[np.random.choice(len(boxes), k, replace=False)]
    for _ in range(max_iter):
        labels = assign_clusters(boxes, centroids)
        new_centroids = compute_centroids(boxes, labels, k)
        if np.all(centroids == new_centroids):
            break
        centroids = new_centroids
    return centroids

centroids = k_means_iou(boxes, k=5)
print("Centroids:", centroids)
# Out:
# Centroids: [[ 43.632183  48.04598 ]
#  [ 70.28755  105.56223 ]
#  [ 91.29851   88.31343 ]
#  [ 57.207317  84.768295]
#  [ 61.79352   62.012146]]

# %% [markdown]
# ### Задание 4 (4 балла + бонусы за лучшую точность). Обучите модель
#
#
# Ваша цель: $mAP > 0.6$ на валидации.
#
# Можете использовать весь арсенал:
# - использование множества якорных рамок (сформированных вручную или в результате кластеризации)
# - любые изменения функции ошибки
# - любые изменения архитектуры модели и регуляризация
# - аугментации (вспоминаем `torchvision.transforms` и `albumentations`)
# - любая длительность обучения, оптимизатор, расписание для learning rate
#
# Бонусы за повышенную точность:
# - **5 баллов**: $mAP > 0.65$
# - **1 балл** за каждые следующие $0.01$ (т. е. за $mAP > 0.72$ в этом задании вы получите $4 + 12 = 16$ баллов)
#
# **Важно**: перез запуском обучения зафиксируйте `torch.manual_seed()`

# %%
GRID_SIZE = 8
IMAGE_SIZE = 256

ANCHORS = centroids.tolist()
rescaled_anchors = torch.tensor(ANCHORS) / IMAGE_SIZE * GRID_SIZE

train_dataset = YeastDetectionDataset(
    Path("yeast_cell_in_microstructures_dataset/train"), anchors=ANCHORS, image_size=256
)
val_dataset = YeastDetectionDataset(Path("yeast_cell_in_microstructures_dataset/val"), anchors=ANCHORS, image_size=256
)

batch_size = 10
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

# %%
class CNNBlock(nn.Module):
    def __init__(self, in_channels: int, out_channels: int, **kwargs):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels)
        self.activation = nn.LeakyReLU(0.1)

    def forward(self, x: Tensor) -> Tensor:
        x = self.conv(x)
        x = self.bn(x)
        return self.activation(x)

class ResidualBlock(nn.Module):
    def __init__(self, inplanes: int, planes: int) -> None:
        super().__init__()
        self.conv1 = nn.Conv2d(
            inplanes, planes, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(
            planes, planes, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv0 = nn.Conv2d(
            inplanes, planes, kernel_size=1, bias=False
        )

    def forward(self, x: Tensor) -> Tensor:
        # сохраним входной тензор на будущее
        identity = x

        out_no_skip = self.relu(self.bn1(self.conv1(x)))
        out_no_skip = self.bn2(self.conv2(out_no_skip))
        out_skip = self.conv0(x)
        out = out_no_skip + out_skip
        out = self.relu(out)
        return out

class JuniorYOLO(nn.Module):
    def __init__(self, num_classes: int = 2, num_anchors: int = 1, in_channels: int = 1) -> None:
        super().__init__()
        self.num_classes = num_classes
        self.num_anchors = num_anchors

        self.layers = nn.Sequential(
            CNNBlock(in_channels, 32, kernel_size=3, stride=2, padding=1),
            CNNBlock(32, 64, kernel_size=3, stride=2, padding=1),
            ResidualBlock(64, 64),
            CNNBlock(64, 128, kernel_size=3, stride=2, padding=1),
            ResidualBlock(128, 128),
            CNNBlock(128, 256, kernel_size=3, stride=2, padding=1),
            ResidualBlock(256, 256),
            CNNBlock(256, 512, kernel_size=3, stride=2, padding=1),
            nn.Conv2d(512, num_anchors * (num_classes + 5), kernel_size=1)
        )


    def forward(self, x: Tensor) -> Tensor:
        x = self.layers(x)
        B, _, W, H = x.shape
        x = x.view(B, self.num_anchors, self.num_classes + 5, W, H)  # B A F W H
        x = x.permute(0, 1, 3, 4, 2)  # B A W H F
        return x

# %%
class Lit(L.LightningModule):
    def __init__(self, model: nn.Module, learning_rate: float, loss_func) -> None:
        super().__init__()
        self.save_hyperparameters(ignore=['model'])
        self.model = model
        self.learning_rate = learning_rate
        self.loss_func = loss_func
        self.metric = MeanAveragePrecision(iou_type="bbox", box_format="cxcywh", class_metrics=True)

    def training_step(
        self, batch: tuple[Tensor, Tensor], batch_idx: int
    ) -> STEP_OUTPUT:
        x, y = batch
        preds = self.model(x)

        loss = self.loss_func(preds, y, rescaled_anchors)
        self.log("train_loss", loss, on_epoch=True, on_step=False, prog_bar=True)
        return loss

    def validation_step(
        self, batch: tuple[Tensor, Tensor], batch_idx: int
    ) -> STEP_OUTPUT | None:
        x, y = batch
        preds = self.model(x)

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        preds = preds.to(device)
        y = y.to(device)

        loss = self.loss_func(preds, y, rescaled_anchors)

        predicted_boxes = cells_to_bboxes(preds, rescaled_anchors.to(device), is_predictions=True)
        target_boxes = cells_to_bboxes(y, rescaled_anchors.to(device))

        preds = [{'boxes': predicted_boxes[:, 2:], 'scores': predicted_boxes[:, 1], 'labels': predicted_boxes[:, 0].long()}]
        targets = [{'boxes': target_boxes[:, 2:], 'labels': target_boxes[:, 0].long()}]

        self.log("val_loss", loss, on_epoch=True, on_step=False, prog_bar=True)
        self.metric.update(preds, targets)
        metric_dict = self.metric.compute()
        self.log('val_map', metric_dict['map'],  prog_bar=True)
        self.metric.reset()

    def configure_optimizers(self) -> dict[str, Any]:
        optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate, weight_decay=1e-5)
        return {
            "optimizer": optimizer,
            "lr_scheduler": torch.optim.lr_scheduler.MultiStepLR(
                optimizer, milestones=[20, 30], gamma=0.25,
            ),
        }

# %%
torch.manual_seed(111)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = JuniorYOLO(in_channels=1, num_anchors=len(rescaled_anchors), num_classes=2).to(device)
loss_func = YOLOLoss()

trainer = L.Trainer(
    accelerator='auto',
    max_epochs=40,
    limit_train_batches=None,
    limit_val_batches=None,
    log_every_n_steps=10,
    logger=CSVLogger(save_dir=".", version=2),
)
lit_module = Lit(
    model=model,
    learning_rate=0.001,
    loss_func=loss_func,
).to(device)
trainer.fit(
    lit_module,
    train_loader,
    val_loader
)

trainer.validate(model=lit_module, dataloaders=val_loader)
# Out:
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name      | Type                 | Params | Mode
# -----------------------------------------------------------
# 0 | model     | JuniorYOLO           | 3.2 M  | train
# 1 | loss_func | YOLOLoss             | 0      | train
# 2 | metric    | MeanAveragePrecision | 0      | train
# -----------------------------------------------------------
# 3.2 M     Trainable params
# 0         Non-trainable params
# 3.2 M     Total params
# 12.892    Total estimated model params size (MB)
# 49        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=40` reached.
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         val_loss          │    0.06454317271709442    │
# │          val_map          │    0.4817955493927002     │
# └───────────────────────────┴───────────────────────────┘
# [{'val_loss': 0.06454317271709442, 'val_map': 0.4817955493927002}]
